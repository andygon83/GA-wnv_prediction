# %%
import numpy as np

# %%
import pandas as pd

# %%
data= pd.read_csv('train.csv')

# %%
data.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
data.set_index(data.Date)
# Out:
#                   Date                                            Address  \
# Date
# 2007-05-29  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29  2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2007-05-29  2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 2007-05-29  2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-05-29  2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-05-29  2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 2007-05-29  2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 2007-05-29  2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...

# %%
pd.to_datetime(data.Date, format='%Y-%m-%d')
# Out:
# 0       2007-05-29
# 1       2007-05-29
# 2       2007-05-29
# 3       2007-05-29
# 4       2007-05-29
# 5       2007-05-29
# 6       2007-05-29
# 7       2007-05-29
# 8       2007-05-29
# 9       2007-05-29
# 10      2007-05-29
# 11      2007-05-29
# 12      2007-05-29
# 13      2007-05-29
# 14      2007-05-29
# 15      2007-05-29
# 16      2007-05-29
# 17      2007-05-29
# 18      2007-05-29
# 19      2007-05-29
# 20      2007-05-29
# 21      2007-05-29
# 22      2007-05-29
# 23      2007-05-29
# 24      2007-05-29
# 25      2007-06-05
# 26      2007-06-05
# 27      2007-06-05
# 28      2007-06-05
# 29      2007-06-05
#            ...
# 10476   2013-09-26
# 10477   2013-09-26
# 10478   2013-09-26
# 10479   2013-09-26
# 10480   2013-09-26
# 10481   2013-09-26
# 10482   2013-09-26
# 10483   2013-09-26
# 10484   2013-09-26
# 10485   2013-09-26
# 10486   2013-09-26
# 10487   2013-09-26
# 10488   2013-09-26
# 10489   2013-09-26
# 10490   2013-09-26
# 10491   2013-09-26
# ...

# %%
import datetime

# %%
data.index = data['Date']

# %%
data['Date'].resample('M')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f0e88a4e33ff> in <module>()
# ----> 1 data['Date'].resample('M')
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4582                      axis=axis, kind=kind, loffset=loffset,
#    4583                      convention=convention,
# -> 4584                      base=base, key=on, level=level)
#    4585         return _maybe_process_deprecations(r,
#    4586                                            how=how,
#
# /anaconda/lib/python2.7/site-packages/pandas/core/resample.pyc in resample(obj, kind, **kwds)
#     961     """ create a TimeGrouper and return our resampler """
#     962     tg = TimeGrouper(**kwds)
# --> 963     return tg._get_resampler(obj, kind=kind)
#     964
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(data.NumMosquitos)
plt.show()
